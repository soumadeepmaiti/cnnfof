# %%
import gadget4_reader as g4

snap = g4.read_snapshot(
    "/ptmp/ccorrea/Aletheia-ML/L200-N32/set1/nbody/runs/output_run0000/snapshot_000",
    h=0.67
)

# save — just give the base output directory, subfolders are created automatically
g4.save_snapshot(snap, "/u/masou/My_Workspace/Git/haloes/Aletheia_halo_finder/cnnfof/snapshots", fmt="bin")

g4.save_snapshot(snap, "/u/masou/My_Workspace/Git/haloes/Aletheia_halo_finder/cnnfof/snapshots", fmt="ascii")
# Out:
# Saved 32,768 particles  →  /u/masou/My_Workspace/Git/haloes/Aletheia_halo_finder/cnnfof/snapshots/bin/snapshot_000.npz
# Saved 32,768 particles  →  /u/masou/My_Workspace/Git/haloes/Aletheia_halo_finder/cnnfof/snapshots/ascii/snapshot_000.txt
# '/u/masou/My_Workspace/Git/haloes/Aletheia_halo_finder/cnnfof/snapshots/ascii/snapshot_000.txt'

# %%
import gadget4_reader as g4
import data      as dp

# ── single run ─────────────────────────────────────────
snap = g4.read_snapshot(
    '/ptmp/ccorrea/Aletheia-ML/L200-N32/set1/nbody/runs/output_run0000/snapshot_000',
    h=0.67
)
df = dp.process_run(
    run_idx       = 0,
    snap          = snap,
    rockstar_base = '/u/masou/My_Workspace/Git/haloes/halo_finder/R200b/L200-N32/rockstar_output/output_run',
    output_base   = '/u/masou/My_Workspace/Git/haloes/Aletheia_halo_finder/cnnfof/data',
    radius_def    = 'r200b',
    h             = 0.67,
)

# ── all runs ──────────────────────────────────────────────────────────────────
dp.process_all_runs(
    n_runs          = 10,
    snapshot_reader = g4.read_snapshot,       # ← pass the function
    snapshot_base   = '/ptmp/ccorrea/Aletheia-ML/L200-N32/set1/nbody/runs/output_run',
    rockstar_base   = '/u/masou/My_Workspace/Git/haloes/halo_finder/R200b/L200-N32/rockstar_output/output_run',
    output_base     = '/u/masou/My_Workspace/Git/haloes/Aletheia_halo_finder/cnnfof/data',
    radius_def      = 'r200b',
    h               = 0.67,
    min_particles   = 25,
)
# Out:
# [0000] done  |  32,768 particles  (halo 0 / field 32,768)  -1 halos  -> ['/u/masou/My_Workspace/Git/haloes/Aletheia_halo_finder/cnnfof/data/ascii/0000.ascii', '/u/masou/My_Workspace/Git/haloes/Aletheia_halo_finder/cnnfof/data/bin/0000.bin']
# Starting data prep  |  radius_def=r200b  min_particles=25  runs=10
#   snapshot -> /ptmp/ccorrea/Aletheia-ML/L200-N32/set1/nbody/runs/output_run<run>/snapshot_000
#   rockstar -> /u/masou/My_Workspace/Git/haloes/halo_finder/R200b/L200-N32/rockstar_output/output_run<run>/
#   output   -> /u/masou/My_Workspace/Git/haloes/Aletheia_halo_finder/cnnfof/data/
#
# [0000] done  |  32,768 particles  (halo 0 / field 32,768)  -1 halos  -> ['/u/masou/My_Workspace/Git/haloes/Aletheia_halo_finder/cnnfof/data/ascii/0000.ascii', '/u/masou/My_Workspace/Git/haloes/Aletheia_halo_finder/cnnfof/data/bin/0000.bin']
# [0001] done  |  32,768 particles  (halo 1,473 / field 31,295)  32 halos  -> ['/u/masou/My_Workspace/Git/haloes/Aletheia_halo_finder/cnnfof/data/ascii/0001.ascii', '/u/masou/My_Workspace/Git/haloes/Aletheia_halo_finder/cnnfof/data/bin/0001.bin']
# [0002] done  |  32,768 particles  (halo 1,777 / field 30,991)  26 halos  -> ['/u/masou/My_Workspace/Git/haloes/Aletheia_halo_finder/cnnfof/data/ascii/0002.ascii', '/u/masou/My_Workspace/Git/haloes/Aletheia_halo_finder/cnnfof/data/bin/0002.bin']
# [0003] done  |  32,768 particles  (halo 1,356 / field 31,412)  31 halos  -> ['/u/masou/My_Workspace/Git/haloes/Aletheia_halo_finder/cnnfof/data/ascii/0003.ascii', '/u/masou/My_Workspace/Git/haloes/Aletheia_halo_finder/cnnfof/data/bin/0003.bin']
# [0004] done  |  32,768 particles  (halo 1,814 / field 30,954)  33 halos  -> ['/u/masou/My_Workspace/Git/haloes/Aletheia_halo_finder/cnnfof/data/ascii/0004.ascii', '/u/masou/My_Workspace/Git/haloes/Aletheia_halo_finder/cnnfof/data/bin/0004.bin']
# [0005] done  |  32,768 particles  (halo 1,385 / field 31,383)  35 halos  -> ['/u/masou/My_Workspace/Git/haloes/Aletheia_halo_finder/cnnfof/data/ascii/0005.ascii', '/u/masou/My_Workspace/Git/haloes/Aletheia_halo_finder/cnnfof/data/bin/0005.bin']
# [0006] done  |  32,768 particles  (halo 1,716 / field 31,052)  32 halos  -> ['/u/masou/My_Workspace/Git/haloes/Aletheia_halo_finder/cnnfof/data/ascii/0006.ascii', '/u/masou/My_Workspace/Git/haloes/Aletheia_halo_finder/cnnfof/data/bin/0006.bin']
# [0007] done  |  32,768 particles  (halo 1,703 / field 31,065)  34 halos  -> ['/u/masou/My_Workspace/Git/haloes/Aletheia_halo_finder/cnnfof/data/ascii/0007.ascii', '/u/masou/My_Workspace/Git/haloes/Aletheia_halo_finder/cnnfof/data/bin/0007.bin']
# [0008] done  |  32,768 particles  (halo 1,605 / field 31,163)  29 halos  -> ['/u/masou/My_Workspace/Git/haloes/Aletheia_halo_finder/cnnfof/data/ascii/0008.ascii', '/u/masou/My_Workspace/Git/haloes/Aletheia_halo_finder/cnnfof/data/bin/0008.bin']
# [0009] done  |  32,768 particles  (halo 1,537 / field 31,231)  35 halos  -> ['/u/masou/My_Workspace/Git/haloes/Aletheia_halo_finder/cnnfof/data/ascii/0009.ascii', '/u/masou/My_Workspace/Git/haloes/Aletheia_halo_finder/cnnfof/data/bin/0009.bin']
#
# Finished  |  10 runs OK  |  0 skipped  |  6.0s  (0.6s/run)

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_pickle('/u/masou/My_Workspace/Git/haloes/Aletheia_halo_finder/cnnfof/data/bin/0003.bin')

field = df[df['Host'] == 0]
halo  = df[df['Host'] == 1]

fig, ax = plt.subplots(figsize=(10, 10))
ax.scatter(field['Px'], field['Py'], s=1, c='steelblue', alpha=0.2, label='field')
ax.scatter(halo['Px'], halo['Py'], s=3, c='limegreen', alpha=1.0, label='halo-parts')
ax.scatter(halo['Hx'],  halo['Hy'],  s=50, c='tomato', marker='x',   alpha=1, label='halo-centre')
ax.set(xlabel='X [Mpc]', ylabel='Y [Mpc]')
# ax.legend(markerscale=6)
plt.tight_layout()
plt.show()

print(f"Particles: {len(df):,}  |  halo: {len(halo):,}  |  field: {len(field):,}")
# Out:
# Particles: 32,768  |  halo: 1,356  |  field: 31,412
